# %%
import sys
sys.path.append('../') # or just install the module
sys.path.append('../../fuzzy-tools') # or just install the module
sys.path.append('../../astro-lightcurves-handler') # or just install the module

# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
from fuzzytools.files import load_pickle, save_pickle
from fuzzytools.files import get_dict_from_filedir
from fuzzytools.lists import check_lists_are_different, check_lists_are_equal

def get_lcdataset(method,
    verbose=1,
    ):
    filedir = f'../../surveys-save/survey=alerceZTFv7.1~bands=gr~mode=onlySNe~method={method}.splcds'
    if verbose:
        print(filedir)
    filedict = get_dict_from_filedir(filedir)
    root_folder = filedict['_rootdir']
    cfilename = filedict['_cfilename']
    survey = filedict['survey']
    lcdataset = load_pickle(filedir)
    return lcdataset


methods = [
    'linear-fstw',
    'bspline-fstw',
    'spm-mcmc-estw',
    'spm-mcmc-fstw',
    ]
kfs = list(range(0, 5))
for method in methods:
    lcdataset = get_lcdataset(method)
    for kf in kfs:
        print(f'kf={kf}')
        set_names = [f'{kf}@train', f'{kf}@val', f'{kf}@test', f'{kf}@train.{method}']
        for set_name in set_names:
            print(set_name)
            lcobjs = lcdataset[set_name].get_lcobjs()
            for lcobj in lcobjs:
                band_names = lcobj.bands
                days = []
                for b in band_names:
                    days += lcobj.get_b(b).days.tolist()
                min_day = min(days)
                assert min_day==0
# Out:
# ../../surveys-save/survey=alerceZTFv7.1~bands=gr~mode=onlySNe~method=linear-fstw.splcds
# kf=0
# 0@train
# 0@val
# 0@test
# 0@train.linear-fstw
# kf=1
# 1@train
# 1@val
# 1@test
# 1@train.linear-fstw
# kf=2
# 2@train
# 2@val
# 2@test
# 2@train.linear-fstw
# kf=3
# 3@train
# 3@val
# 3@test
# 3@train.linear-fstw
# kf=4
# 4@train
# 4@val
# 4@test
# 4@train.linear-fstw
# ../../surveys-save/survey=alerceZTFv7.1~bands=gr~mode=onlySNe~method=bspline-fstw.splcds
# kf=0
# 0@train
# 0@val
# 0@test
# 0@train.bspline-fstw
# kf=1
# 1@train
# 1@val
# 1@test
# 1@train.bspline-fstw
# kf=2
# 2@train
# 2@val
# 2@test
# 2@train.bspline-fstw
# kf=3
# 3@train
# 3@val
# 3@test
# 3@train.bspline-fstw
# kf=4
# 4@train
# 4@val
# 4@test
# 4@train.bspline-fstw
# ../../surveys-save/survey=alerceZTFv7.1~bands=gr~mode=onlySNe~method=spm-mcmc-estw.splcds
# kf=0
# 0@train
# 0@val
# 0@test
# 0@train.spm-mcmc-estw
# kf=1
# 1@train
# 1@val
# 1@test
# 1@train.spm-mcmc-estw
# kf=2
# 2@train
# 2@val
# 2@test
# 2@train.spm-mcmc-estw
# kf=3
# 3@train
# 3@val
# 3@test
# 3@train.spm-mcmc-estw
# kf=4
# 4@train
# 4@val
# 4@test
# 4@train.spm-mcmc-estw
# ../../surveys-save/survey=alerceZTFv7.1~bands=gr~mode=onlySNe~method=spm-mcmc-fstw.splcds
# kf=0
# 0@train
# 0@val
# 0@test
# 0@train.spm-mcmc-fstw
# kf=1
# 1@train
# 1@val
# 1@test
# 1@train.spm-mcmc-fstw
# kf=2
# 2@train
# 2@val
# 2@test
# 2@train.spm-mcmc-fstw
# kf=3
# 3@train
# 3@val
# 3@test
# 3@train.spm-mcmc-fstw
# kf=4
# 4@train
# 4@val
# 4@test
# 4@train.spm-mcmc-fstw

# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
from fuzzytools.files import load_pickle, save_pickle
from fuzzytools.files import get_dict_from_filedir
from fuzzytools.lists import check_lists_are_different, check_lists_are_equal

def get_lcdataset(method,
    verbose=1,
    ):
    filedir = f'../../surveys-save/survey=alerceZTFv7.1~bands=gr~mode=onlySNe~method={method}.splcds'
    if verbose:
        print(filedir)
    filedict = get_dict_from_filedir(filedir)
    root_folder = filedict['_rootdir']
    cfilename = filedict['_cfilename']
    survey = filedict['survey']
    lcdataset = load_pickle(filedir)
    return lcdataset


methods = [
    'linear-fstw',
    'bspline-fstw',
    'spm-mcmc-estw',
    'spm-mcmc-fstw',
    ]
kfs = list(range(0, 5))
for method in methods:
    lcdataset = get_lcdataset(method)
    for kf in kfs:
        print(f'kf={kf}')
        train_lcobj_names = lcdataset[f'{kf}@train'].get_lcobj_names()
        val_lcobj_names = lcdataset[f'{kf}@val'].get_lcobj_names()
        test_lcobj_names = lcdataset[f'{kf}@test'].get_lcobj_names()
        synth_train_lcobj_names = lcdataset[f'{kf}@train.{method}'].get_lcobj_names()
        new_synth_train_lcobj_names = list(set([n.split('.')[0] for n in synth_train_lcobj_names]))
        
        print(f'train {len(train_lcobj_names)}/train {len(train_lcobj_names)}')
        assert check_lists_are_equal(train_lcobj_names, train_lcobj_names)
        
        print(f'train {len(train_lcobj_names)}/val {len(val_lcobj_names)}')
        assert check_lists_are_different(train_lcobj_names, val_lcobj_names)
        
        print(f'train {len(train_lcobj_names)}/test {len(test_lcobj_names)}')
        assert check_lists_are_different(train_lcobj_names, test_lcobj_names)
        
        print(f'val {len(val_lcobj_names)}/test {len(test_lcobj_names)}')
        assert check_lists_are_different(val_lcobj_names, test_lcobj_names)

        print(f'train {len(train_lcobj_names)}/synth_train {len(synth_train_lcobj_names)}')
        assert check_lists_are_different(train_lcobj_names, synth_train_lcobj_names)
        
        print(f'train {len(train_lcobj_names)}/new_synth_train {len(new_synth_train_lcobj_names)}')
        assert check_lists_are_equal(train_lcobj_names, new_synth_train_lcobj_names)
        
        print(f'new_synth_train {len(new_synth_train_lcobj_names)}/val {len(val_lcobj_names)}')
        assert check_lists_are_different(new_synth_train_lcobj_names, val_lcobj_names)
        
        print(f'new_synth_train {len(new_synth_train_lcobj_names)}/test {len(test_lcobj_names)}')
        assert check_lists_are_different(new_synth_train_lcobj_names, test_lcobj_names)
        
        for other_method in methods:
            if method==other_method:
                continue
            other_lcdataset = get_lcdataset(other_method, verbose=0)
            other_train_lcobj_names = other_lcdataset[f'{kf}@train'].get_lcobj_names()
            other_val_lcobj_names = other_lcdataset[f'{kf}@val'].get_lcobj_names()
            other_test_lcobj_names = other_lcdataset[f'{kf}@test'].get_lcobj_names()
            
            print(f'train {len(train_lcobj_names)}/train {len(other_train_lcobj_names)} from {other_method}')
            assert check_lists_are_equal(train_lcobj_names, other_train_lcobj_names)
            
            print(f'val {len(val_lcobj_names)}/val {len(other_val_lcobj_names)} from {other_method}')
            assert check_lists_are_equal(val_lcobj_names, other_val_lcobj_names)
            
            print(f'test {len(test_lcobj_names)}/test {len(other_test_lcobj_names)} from {other_method}')
            assert check_lists_are_equal(test_lcobj_names, other_test_lcobj_names)
    print()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ../../surveys-save/survey=alerceZTFv7.1~bands=gr~mode=onlySNe~method=linear-fstw.splcds
# kf=0
# train 1185/train 1185
# train 1185/val 395
# train 1185/test 395
# val 395/test 395
# train 1185/synth_train 37920
# train 1185/new_synth_train 1185
# new_synth_train 1185/val 395
# new_synth_train 1185/test 395
# train 1185/train 1185 from bspline-fstw
# val 395/val 395 from bspline-fstw
# test 395/test 395 from bspline-fstw
# train 1185/train 1185 from spm-mcmc-estw
# val 395/val 395 from spm-mcmc-estw
# test 395/test 395 from spm-mcmc-estw
# train 1185/train 1185 from spm-mcmc-fstw
# val 395/val 395 from spm-mcmc-fstw
# test 395/test 395 from spm-mcmc-fstw
# kf=1
# train 1184/train 1184
# train 1184/val 395
# train 1184/test 396
# val 395/test 396
# train 1184/synth_train 37888
# train 1184/new_synth_train 1184
# new_synth_train 1184/val 395
# new_synth_train 1184/test 396
# train 1184/train 1184 from bspline-fstw
# val 395/val 395 from bspline-fstw
# test 396/test 396 from bspline-fstw
# train 1184/train 1184 from spm-mcmc-estw
# val 395/val 395 from spm-mcmc-estw
# test 396/test 396 from spm-mcmc-estw
# train 1184/train 1184 from spm-mcmc-fstw
# val 395/val 395 from spm-mcmc-fstw
# test 396/test 396 from spm-mcmc-fstw
# kf=2
# train 1185/train 1185
# train 1185/val 396
# train 1185/test 395
# val 396/test 395
# train 1185/synth_train 37920
# train 1185/new_synth_train 1185
# new_synth_train 1185/val 396
# new_synth_train 1185/test 395
# train 1185/train 1185 from bspline-fstw
# val 396/val 396 from bspline-fstw
# test 395/test 395 from bspline-fstw
# train 1185/train 1185 from spm-mcmc-estw
# val 396/val 396 from spm-mcmc-estw
# test 395/test 395 from spm-mcmc-estw
# train 1185/train 1185 from spm-mcmc-fstw
# val 396/val 396 from spm-mcmc-fstw
# test 395/test 395 from spm-mcmc-fstw
# kf=3
# train 1185/train 1185
# train 1185/val 395
# train 1185/test 396
# val 395/test 396
# train 1185/synth_train 37920
# train 1185/new_synth_train 1185
# new_synth_train 1185/val 395
# new_synth_train 1185/test 396
# train 1185/train 1185 from bspline-fstw
# val 395/val 395 from bspline-fstw
# test 396/test 396 from bspline-fstw
# train 1185/train 1185 from spm-mcmc-estw
# val 395/val 395 from spm-mcmc-estw
# test 396/test 396 from spm-mcmc-estw
# train 1185/train 1185 from spm-mcmc-fstw
# val 395/val 395 from spm-mcmc-fstw
# test 396/test 396 from spm-mcmc-fstw
# kf=4
# train 1185/train 1185
# train 1185/val 396
# train 1185/test 395
# val 396/test 395
# train 1185/synth_train 37920
# train 1185/new_synth_train 1185
# new_synth_train 1185/val 396
# new_synth_train 1185/test 395
# train 1185/train 1185 from bspline-fstw
# val 396/val 396 from bspline-fstw
# test 395/test 395 from bspline-fstw
# train 1185/train 1185 from spm-mcmc-estw
# val 396/val 396 from spm-mcmc-estw
# test 395/test 395 from spm-mcmc-estw
# train 1185/train 1185 from spm-mcmc-fstw
# val 396/val 396 from spm-mcmc-fstw
# test 395/test 395 from spm-mcmc-fstw
#
# ../../surveys-save/survey=alerceZTFv7.1~bands=gr~mode=onlySNe~method=bspline-fstw.splcds
# kf=0
# train 1185/train 1185
# train 1185/val 395
# train 1185/test 395
# val 395/test 395
# train 1185/synth_train 37920
# train 1185/new_synth_train 1185
# new_synth_train 1185/val 395
# new_synth_train 1185/test 395
# train 1185/train 1185 from linear-fstw
# val 395/val 395 from linear-fstw
# test 395/test 395 from linear-fstw
# train 1185/train 1185 from spm-mcmc-estw
# val 395/val 395 from spm-mcmc-estw
# test 395/test 395 from spm-mcmc-estw
# train 1185/train 1185 from spm-mcmc-fstw
# val 395/val 395 from spm-mcmc-fstw
# test 395/test 395 from spm-mcmc-fstw
# kf=1
# train 1184/train 1184
# train 1184/val 395
# train 1184/test 396
# val 395/test 396
# train 1184/synth_train 37888
# train 1184/new_synth_train 1184
# new_synth_train 1184/val 395
# new_synth_train 1184/test 396
# train 1184/train 1184 from linear-fstw
# val 395/val 395 from linear-fstw
# test 396/test 396 from linear-fstw
# train 1184/train 1184 from spm-mcmc-estw
# val 395/val 395 from spm-mcmc-estw
# test 396/test 396 from spm-mcmc-estw
# train 1184/train 1184 from spm-mcmc-fstw
# val 395/val 395 from spm-mcmc-fstw
# test 396/test 396 from spm-mcmc-fstw
# kf=2
# train 1185/train 1185
# train 1185/val 396
# train 1185/test 395
# val 396/test 395
# train 1185/synth_train 37920
# train 1185/new_synth_train 1185
# new_synth_train 1185/val 396
# new_synth_train 1185/test 395
# train 1185/train 1185 from linear-fstw
# val 396/val 396 from linear-fstw
# test 395/test 395 from linear-fstw
# train 1185/train 1185 from spm-mcmc-estw
# val 396/val 396 from spm-mcmc-estw
# test 395/test 395 from spm-mcmc-estw
# train 1185/train 1185 from spm-mcmc-fstw
# val 396/val 396 from spm-mcmc-fstw
# test 395/test 395 from spm-mcmc-fstw
# kf=3
# train 1185/train 1185
# train 1185/val 395
# train 1185/test 396
# val 395/test 396
# train 1185/synth_train 37920
# train 1185/new_synth_train 1185
# new_synth_train 1185/val 395
# new_synth_train 1185/test 396
# train 1185/train 1185 from linear-fstw
# val 395/val 395 from linear-fstw
# test 396/test 396 from linear-fstw
# train 1185/train 1185 from spm-mcmc-estw
# val 395/val 395 from spm-mcmc-estw
# test 396/test 396 from spm-mcmc-estw
# train 1185/train 1185 from spm-mcmc-fstw
# val 395/val 395 from spm-mcmc-fstw
# test 396/test 396 from spm-mcmc-fstw
# kf=4
# train 1185/train 1185
# train 1185/val 396
# train 1185/test 395
# val 396/test 395
# train 1185/synth_train 37920
# train 1185/new_synth_train 1185
# new_synth_train 1185/val 396
# new_synth_train 1185/test 395
# train 1185/train 1185 from linear-fstw
# val 396/val 396 from linear-fstw
# test 395/test 395 from linear-fstw
# train 1185/train 1185 from spm-mcmc-estw
# val 396/val 396 from spm-mcmc-estw
# test 395/test 395 from spm-mcmc-estw
# train 1185/train 1185 from spm-mcmc-fstw
# val 396/val 396 from spm-mcmc-fstw
# test 395/test 395 from spm-mcmc-fstw
#
# ../../surveys-save/survey=alerceZTFv7.1~bands=gr~mode=onlySNe~method=spm-mcmc-estw.splcds
# kf=0
# train 1185/train 1185
# train 1185/val 395
# train 1185/test 395
# val 395/test 395
# train 1185/synth_train 37920
# train 1185/new_synth_train 1185
# new_synth_train 1185/val 395
# new_synth_train 1185/test 395
# train 1185/train 1185 from linear-fstw
# val 395/val 395 from linear-fstw
# test 395/test 395 from linear-fstw
# train 1185/train 1185 from bspline-fstw
# val 395/val 395 from bspline-fstw
# test 395/test 395 from bspline-fstw
# train 1185/train 1185 from spm-mcmc-fstw
# val 395/val 395 from spm-mcmc-fstw
# test 395/test 395 from spm-mcmc-fstw
# kf=1
# train 1184/train 1184
# train 1184/val 395
# train 1184/test 396
# val 395/test 396
# train 1184/synth_train 37888
# train 1184/new_synth_train 1184
# new_synth_train 1184/val 395
# new_synth_train 1184/test 396
# train 1184/train 1184 from linear-fstw
# val 395/val 395 from linear-fstw
# test 396/test 396 from linear-fstw
# train 1184/train 1184 from bspline-fstw
# val 395/val 395 from bspline-fstw
# test 396/test 396 from bspline-fstw
# train 1184/train 1184 from spm-mcmc-fstw
# val 395/val 395 from spm-mcmc-fstw
# test 396/test 396 from spm-mcmc-fstw
# kf=2
# train 1185/train 1185
# train 1185/val 396
# train 1185/test 395
# val 396/test 395
# train 1185/synth_train 37920
# train 1185/new_synth_train 1185
# new_synth_train 1185/val 396
# new_synth_train 1185/test 395
# train 1185/train 1185 from linear-fstw
# val 396/val 396 from linear-fstw
# test 395/test 395 from linear-fstw
# train 1185/train 1185 from bspline-fstw
# val 396/val 396 from bspline-fstw
# test 395/test 395 from bspline-fstw
# train 1185/train 1185 from spm-mcmc-fstw
# val 396/val 396 from spm-mcmc-fstw
# test 395/test 395 from spm-mcmc-fstw
# kf=3
# train 1185/train 1185
# train 1185/val 395
# train 1185/test 396
# val 395/test 396
# train 1185/synth_train 37920
# train 1185/new_synth_train 1185
# new_synth_train 1185/val 395
# new_synth_train 1185/test 396
# train 1185/train 1185 from linear-fstw
# val 395/val 395 from linear-fstw
# test 396/test 396 from linear-fstw
# train 1185/train 1185 from bspline-fstw
# val 395/val 395 from bspline-fstw
# test 396/test 396 from bspline-fstw
# train 1185/train 1185 from spm-mcmc-fstw
# val 395/val 395 from spm-mcmc-fstw
# test 396/test 396 from spm-mcmc-fstw
# kf=4
# train 1185/train 1185
# train 1185/val 396
# train 1185/test 395
# val 396/test 395
# train 1185/synth_train 37920
# train 1185/new_synth_train 1185
# new_synth_train 1185/val 396
# new_synth_train 1185/test 395
# train 1185/train 1185 from linear-fstw
# val 396/val 396 from linear-fstw
# test 395/test 395 from linear-fstw
# train 1185/train 1185 from bspline-fstw
# val 396/val 396 from bspline-fstw
# test 395/test 395 from bspline-fstw
# train 1185/train 1185 from spm-mcmc-fstw
# val 396/val 396 from spm-mcmc-fstw
# test 395/test 395 from spm-mcmc-fstw
#
# ../../surveys-save/survey=alerceZTFv7.1~bands=gr~mode=onlySNe~method=spm-mcmc-fstw.splcds
# kf=0
# train 1185/train 1185
# train 1185/val 395
# train 1185/test 395
# val 395/test 395
# train 1185/synth_train 37920
# train 1185/new_synth_train 1185
# new_synth_train 1185/val 395
# new_synth_train 1185/test 395
# train 1185/train 1185 from linear-fstw
# val 395/val 395 from linear-fstw
# test 395/test 395 from linear-fstw
# train 1185/train 1185 from bspline-fstw
# val 395/val 395 from bspline-fstw
# test 395/test 395 from bspline-fstw
# train 1185/train 1185 from spm-mcmc-estw
# val 395/val 395 from spm-mcmc-estw
# test 395/test 395 from spm-mcmc-estw
# kf=1
# train 1184/train 1184
# train 1184/val 395
# train 1184/test 396
# val 395/test 396
# train 1184/synth_train 37888
# train 1184/new_synth_train 1184
# new_synth_train 1184/val 395
# new_synth_train 1184/test 396
# train 1184/train 1184 from linear-fstw
# val 395/val 395 from linear-fstw
# test 396/test 396 from linear-fstw
# train 1184/train 1184 from bspline-fstw
# val 395/val 395 from bspline-fstw
# test 396/test 396 from bspline-fstw
# train 1184/train 1184 from spm-mcmc-estw
# val 395/val 395 from spm-mcmc-estw
# test 396/test 396 from spm-mcmc-estw
# kf=2
# train 1185/train 1185
# train 1185/val 396
# train 1185/test 395
# val 396/test 395
# train 1185/synth_train 37920
# train 1185/new_synth_train 1185
# new_synth_train 1185/val 396
# new_synth_train 1185/test 395
# train 1185/train 1185 from linear-fstw
# val 396/val 396 from linear-fstw
# test 395/test 395 from linear-fstw
# train 1185/train 1185 from bspline-fstw
# val 396/val 396 from bspline-fstw
# test 395/test 395 from bspline-fstw
# train 1185/train 1185 from spm-mcmc-estw
# val 396/val 396 from spm-mcmc-estw
# test 395/test 395 from spm-mcmc-estw
# kf=3
# train 1185/train 1185
# train 1185/val 395
# train 1185/test 396
# val 395/test 396
# train 1185/synth_train 37920
# train 1185/new_synth_train 1185
# new_synth_train 1185/val 395
# new_synth_train 1185/test 396
# train 1185/train 1185 from linear-fstw
# val 395/val 395 from linear-fstw
# test 396/test 396 from linear-fstw
# train 1185/train 1185 from bspline-fstw
# val 395/val 395 from bspline-fstw
# test 396/test 396 from bspline-fstw
# train 1185/train 1185 from spm-mcmc-estw
# val 395/val 395 from spm-mcmc-estw
# test 396/test 396 from spm-mcmc-estw
# kf=4
# train 1185/train 1185
# train 1185/val 396
# train 1185/test 395
# val 396/test 395
# train 1185/synth_train 37920
# train 1185/new_synth_train 1185
# new_synth_train 1185/val 396
# new_synth_train 1185/test 395
# train 1185/train 1185 from linear-fstw
# val 396/val 396 from linear-fstw
# test 395/test 395 from linear-fstw
# train 1185/train 1185 from bspline-fstw
# val 396/val 396 from bspline-fstw
# test 395/test 395 from bspline-fstw
# train 1185/train 1185 from spm-mcmc-estw
# val 396/val 396 from spm-mcmc-estw
# test 395/test 395 from spm-mcmc-estw
