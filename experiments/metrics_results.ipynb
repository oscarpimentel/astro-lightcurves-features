# %%
import sys
sys.path.append('../') # or just install the module
sys.path.append('../../fuzzy-tools') # or just install the module
sys.path.append('../../astro-lightcurves-handler') # or just install the module

# %%
# %load_ext autoreload
# %autoreload 2
from lcfeatures.results.utils import get_model_names

rootdir = '../save'
set_name = 'test'
method = 'spm-mcmc-estw'
cfilename = f'survey=alerceZTFv7.1~bands=gr~mode=onlySNe~method={method}'
kf = '.'

model_names = get_model_names(rootdir, cfilename, kf, set_name)
model_names
# Out:
# ['method=spm-mcmc-estw~train_mode=r~fats_mode=all',
#  'method=spm-mcmc-fstw~train_mode=s~fats_mode=all',
#  'method=bspline-fstw~train_mode=r+s~fats_mode=all',
#  'method=linear-fstw~train_mode=r+s~fats_mode=all',
#  'method=spm-mcmc-estw~train_mode=r+s~fats_mode=all',
#  'method=spm-mcmc-fstw~train_mode=r+s~fats_mode=all',
#  'method=bspline-fstw~train_mode=s~fats_mode=all',
#  'method=linear-fstw~train_mode=s~fats_mode=all',
#  'method=spm-mcmc-estw~train_mode=s~fats_mode=all']

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import numpy as np
import fuzzytools.files as ftfiles
import fuzzytools.strings as ftstrings
from fuzzytools.datascience.cms import ConfusionMatrix
from fuzzytools.matplotlib.cm_plots import plot_custom_confusion_matrix
import matplotlib.pyplot as plt
from fuzzytools.datascience.xerror import XError
from IPython.display import display
from fuzzytools.strings import latex_bf_alphabet_count
from fuzzytools.latex.latex_tables import LatexTable
from fuzzytools.matplotlib.utils import save_fig
import fuzzytools.strings as strings

methods = [
    'spm-mcmc-estw',
    'spm-mcmc-fstw',
    'linear-fstw',
    'bspline-fstw',
    ]

RANDOM_STATE = None
set_name = 'test'
kf = '.'
thday = 100

for model_name in model_names:
    model_name_d = strings.get_dict_from_string(model_name)
    method = model_name_d['method']
    load_roodir = f'../save/{model_name}/performance/survey=alerceZTFv7.1~bands=gr~mode=onlySNe~method={method}'
    print(load_roodir)
    files, files_ids, kfs = ftfiles.gather_files_by_kfold(load_roodir, kf, set_name,
        fext='d',
        imbalanced_kf_mode='oversampling', # error oversampling
        random_state=RANDOM_STATE,
        )
    
    print(f'{files_ids}({len(files_ids)}#)')
    if len(files)==0:
        continue

    class_names = files[0]()['class_names']
    features = files[0]()['features']
    rank = files[0]()['rank']
    for f in features:
        #print(f)
        pass
    thdays = files[0]()['thdays']
    thday = thdays[np.argmin((np.array(thdays)-thday)**2)]

    xe_dict = {}
    for metric_name in ['recall', 'f1score']:
        xe_metric = XError([f()['thdays_class_metrics_df'].loc[f()['thdays_class_metrics_df']['_thday']==thday][f'b-{metric_name}'].item() for f in files])
        xe_dict[f'b-{metric_name}'] = xe_metric

    brecall_xe = xe_dict['b-recall']
    bf1score_xe = xe_dict['b-f1score']

    new_order_class_names = ['SNIa', 'SNIbc', 'SNIIbn', 'SLSN']
    new_order_class_names = ['SNIa', 'SNIbc', 'SNII*', 'SLSN']
    cm = ConfusionMatrix([f()['thdays_cm'][thday] for f in files], class_names)
    cm.reorder_classes(new_order_class_names)
    for c in new_order_class_names:
        print(cm.get_diagonal_dict()[c].get_raw_repr(f'brf_{c}_tp'))
        pass
    true_label_d = {c:f'({k}#)' for c,k in zip(class_names, np.sum(files[0]()['thdays_cm'][thday], axis=1))}

    rank = files[0]()['rank'] # just show one
    rank.names = ['Feature name=\\verb+'+n+'+' for n in rank.names]
    rank.values = [v*100 for v in rank.values]
    rank_df = rank.get_df()
    latex_table = LatexTable(rank_df,
        label='tab:brf_ranking',
        )
    #display(rank_df)
    #print(latex_table)

    ### plot cm
    train_mode = model_name_d['train_mode']
    model_name = ftstrings.get_formated_method('BRF', {
        'training-set':f'[{train_mode}]',
        'method':None if train_mode=='r' else method,
        '#features':len(features),
        })
    title = ''
    title += f'{latex_bf_alphabet_count(0)} {model_name}'+'\n'
    title += f'b-Recall={brecall_xe}; b-$F_1$score={bf1score_xe}'+'\n'
    title += f'th-day={thday:.0f} [days]'+'\n'
    fig, ax = plot_custom_confusion_matrix(cm,
        title=title[:-1],
        figsize=(6,5),
        dpi=200,
        true_label_d=true_label_d,
        lambda_c=lambda x:x.replace('*', ''),
        )
    save_fig(fig, f'../temp/cms_a.pdf', closes_fig=0)
    plt.show()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ../save/method=spm-mcmc-estw~train_mode=r~fats_mode=all/performance/survey=alerceZTFv7.1~bands=gr~mode=onlySNe~method=spm-mcmc-estw
# ['0@id=1000c0', '0@id=1000c1', '0@id=1001c0', '0@id=1001c1', '0@id=1002c0', '0@id=1002c1', '0@id=1003c0', '0@id=1003c1', '0@id=1004c0', '0@id=1004c1', '0@id=1005c0', '0@id=1005c1', '1@id=1000c0', '1@id=1000c1', '1@id=1001c0', '1@id=1001c1', '1@id=1002c0', '1@id=1002c1', '1@id=1003c0', '1@id=1003c1', '1@id=1004c0', '1@id=1004c1', '1@id=1005c0', '1@id=1005c1', '2@id=1000c0', '2@id=1000c1', '2@id=1001c0', '2@id=1001c1', '2@id=1002c0', '2@id=1002c1', '2@id=1003c0', '2@id=1003c1', '2@id=1004c0', '2@id=1004c1', '2@id=1005c0', '2@id=1005c1', '3@id=1000c0', '3@id=1000c1', '3@id=1001c0', '3@id=1001c1', '3@id=1002c0', '3@id=1002c1', '3@id=1003c0', '3@id=1003c1', '3@id=1004c0', '3@id=1004c1', '3@id=1005c0', '3@id=1005c1', '4@id=1000c0', '4@id=1000c1', '4@id=1001c0', '4@id=1001c1', '4@id=1002c0', '4@id=1002c1', '4@id=1003c0', '4@id=1003c1', '4@id=1004c0', '4@id=1004c1', '4@id=1005c0', '4@id=1005c1'](60#)
# brf_SNIa_tp = [74.91638795986621, 72.5752508361204, 78.92976588628763, 76.58862876254182, 75.91973244147158, 75.25083612040135, 74.91638795986621, 76.58862876254182, 76.92307692307693, 76.58862876254182, 76.2541806020067, 78.26086956521739, 77.0, 75.0, 75.0, 78.0, 75.33333333333333, 74.66666666666667, 72.0, 77.66666666666666, 76.0, 77.0, 76.33333333333333, 76.0, 74.0, 73.33333333333333, 70.66666666666667, 76.0, 74.33333333333333, 69.33333333333334, 76.0, 72.66666666666667, 69.0, 72.0, 73.0, 71.33333333333334, 73.0, 75.0, 72.0, 73.33333333333333, 73.0, 76.66666666666667, 74.33333333333333, 72.33333333333334, 69.66666666666667, 75.0, 75.66666666666667, 71.33333333333334, 77.92642140468227, 78.59531772575251, 80.2675585284281, 77.59197324414716, 81.60535117056857, 81.27090301003345, 77.59197324414716, 82.94314381270902, 76.2541806020067, 79.59866220735786, 82.94314381270902, 79.26421404682274]
666666666667, 82.66666666666667, 82.66666666666667, 82.66666666666667, 83.66666666666667, 82.66666666666667, 82.66666666666667, 83.0, 83.0, 81.66666666666667, 81.33333333333333, 83.33333333333334, 84.0, 82.66666666666667, 82.0, 80.66666666666666, 82.33333333333334, 83.0, 83.0, 82.33333333333334, 83.0, 83.0, 80.66666666666666, 83.0, 83.61204013377926, 84.94983277591973, 81.93979933110369, 82.94314381270902, 83.94648829431438, 84.2809364548495, 84.2809364548495, 84.61538461538461, 83.27759197324414, 84.2809364548495, 84.2809364548495, 84.61538461538461]
# brf_SNIbc_tp = [55.00000000000001, 55.00000000000001, 55.00000000000001, 60.0, 55.00000000000001, 55.00000000000001, 55.00000000000001, 55.00000000000001, 55.00000000000001, 55.00000000000001, 50.0, 50.0, 75.0, 75.0, 75.0, 75.0, 75.0, 75.0, 80.0, 75.0, 80.0, 75.0, 80.0, 80.0, 60.0, 65.0, 70.0, 65.0, 65.0, 65.0, 70.0, 70.0, 65.0, 65.0, 70.0, 70.0, 65.0, 65.0, 65.0, 65.0, 65.0, 65.0, 65.0, 65.0, 65.0, 65.0, 65.0, 65.0, 70.0, 65.0, 70.0, 70.0, 70.0, 65.0, 70.0, 55.00000000000001, 70.0, 60.0, 60.0, 65.0]
# brf_SNII*_tp = [50.0, 50.0, 51.42857142857142, 45.714285714285715, 50.0, 51.42857142857142, 51.42857142857142, 50.0, 48.57142857142857, 51.42857142857142, 50.0, 48.57142857142857, 57.14285714285714, 60.0, 55.714285714285715, 57.14285714285714, 58.57142857142858, 57.14285714285714, 58.57142857142858, 57.14285714285714, 55.714285714285715, 57.14285714285714, 57.14285714285714, 58.57142857142858, 59.42028985507246, 59.42028985507246, 57.971014492753625, 55.072463768115945, 59.42028985507246, 62.31884057971014, 63.76811594202898, 59.42028985507246, 59.42028985507246, 57.971014492753625, 56.52173913043478, 63.76811594202898, 68.57142857142857, 70.0, 71.42857142857143, 72.85714285714285, 72.85714285714285, 71.42857142857143, 71.42857142857143, 71.42857142857143, 68.57142857142857, 70.0, 71.42857142857143, 70.0, 68.57142857142857, 62.857142857142854, 67.14285714285714, 68.57142857142857, 70.0, 67.14285714285714, 65.71428571428571, 68.57142857142857, 67.14285714285714, 65.71428571428571, 67.14285714285714, 68.57142857142857]
# brf_SLSN_tp = [83.33333333333334, 83.33333333333334, 83.33333333333334, 83.33333333333334, 83.33333333333334, 83.33333333333334, 83.33333333333334, 83.33333333333334, 83.33333333333334, 83.33333333333334, 83.33333333333334, 83.33333333333334, 50.0, 66.66666666666666, 50.0, 50.0, 50.0, 50.0, 66.66666666666666, 66.66666666666666, 50.0, 50.0, 50.0, 50.0, 66.66666666666666, 66.66666666666666, 50.0, 66.66666666666666, 66.66666666666666, 66.66666666666666, 66.66666666666666, 66.66666666666666, 66.66666666666666, 66.66666666666666, 66.66666666666666, 66.66666666666666, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 83.33333333333334, 83.33333333333334, 83.33333333333334, 83.33333333333334, 83.33333333333334, 83.33333333333334, 83.33333333333334, 83.33333333333334, 83.33333333333334, 83.33333333333334, 83.33333333333334, 83.33333333333334]

# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
from fuzzytools.files import load_pickle, save_pickle
from fuzzytools.datascience.xerror import XError
from fuzzytools.dataframes import DFBuilder
from fuzzytools.latex.latex_tables import LatexTable
from fuzzytools.files import save_pickle
import matplotlib.pyplot as plt
import fuzzytools.matplotlib.fills as fills
import fuzzytools.strings as ftstrings
import fuzzytools.files as ftfiles
import fuzzytools.matplotlib.colors as ftc

DICT_NAME = 'thdays_class_metrics'
dict_name = DICT_NAME
RANDOM_STATE = None
METRICS_D = {
    f'aucroc':{'k':1, 'mn':'AUCROC'},
    f'precision':{'k':1, 'mn':'Precision'},
    f'recall':{'k':1, 'mn':'Recall'},
    f'f1score':{'k':1, 'mn':'$F_1$score'},
    f'aucpr':{'k':1, 'mn':'AUCPR'},
    f'gmean':{'k':1, 'mn':'Gmean'},
    f'accuracy':{'k':1, 'mn':'Accuracy'},
    }

metric_names = [
    'precision',
    'recall',
    'f1score',
    'aucroc',
    'aucpr',
    ]
target_class = None
metric_name = 'aucroc'
figsize = (10,5)
info_df = DFBuilder()
colors = ftc.colors()
fig, ax = plt.subplots(1, 1, figsize=figsize, dpi=200)
for kmn,model_name in enumerate(model_names):
    model_name_d = ftstrings.get_dict_from_string(model_name)
    method = model_name_d['method']
    load_roodir = f'../save/{model_name}/survey=alerceZTFv7.1~bands=gr~mode=onlySNe~method={method}'
    print(load_roodir)
    files, files_ids, kfs = ftfiles.gather_files_by_kfold(load_roodir, kf, set_name,
        fext='d',
        imbalanced_kf_mode='oversampling', # error oversampling
        random_state=RANDOM_STATE,
        )
    
    print(f'{files_ids}({len(files_ids)}#)')
    if len(files)==0:
        continue

        
    thdays = files[0]()['thdays']
    thdays_computed_curves = []
    metric_curves = []
    for f in files:
        thdays_computed_curves += [np.array(f()['thdays_computed'])]
        if target_class is None:
            metric_curve = f()[f'{dict_name}_df'][f'b-{metric_name}'].values
            metric_curves += [metric_curve]
        else:
            metric_curve = f()[f'{dict_name}_cdf'][target_class][f'{metric_name}'].values
            metric_curves += [metric_curve]
    
    color = colors[kmn]
    label = f'{model_name}'
    shadow_alpha = 0.1
    std_prop = .5
    linestyle = ':'
    if model_name_d['train_mode']=='s':
        linestyle = '-.'
    if model_name_d['train_mode']=='r+s':
        linestyle = '-'
    ax, new_x, median_y, yrange = fills.fill_beetween_mean_std(ax, thdays_computed_curves, metric_curves,
        mean_kwargs={'color':color, 'alpha':1, 'linestyle':linestyle, 'marker':'D', 'markersize':0, 'markerfacecolor':'None', 'markevery':[0], 'zorder':-.5, 'label':label},
        fill_kwargs={'color':color, 'alpha':shadow_alpha, 'lw':0, 'zorder':-.5},
        returns_extras=True,
        std_prop=std_prop,
        )
    ax.legend()

# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
from fuzzytools.files import load_pickle, save_pickle
from fuzzytools.datascience.xerror import XError
from fuzzytools.dataframes import DFBuilder
from fuzzytools.latex.latex_tables import LatexTable
from fuzzytools.files import save_pickle
import matplotlib.pyplot as plt
import fuzzytools.matplotlib.fills as fills

METRICS_D = {
    f'aucroc':{'k':1, 'mn':'AUCROC'},
    f'precision':{'k':1, 'mn':'Precision'},
    f'recall':{'k':1, 'mn':'Recall'},
    f'f1score':{'k':1, 'mn':'$F_1$score'},
    f'aucpr':{'k':1, 'mn':'AUCPR'},
    f'gmean':{'k':1, 'mn':'Gmean'},
    f'accuracy':{'k':1, 'mn':'Accuracy'},
    }

metric_names = [
    'precision',
    'recall',
    'f1score',
    'aucroc',
    'aucpr',
    ]

curve_metric_name = 'aucroc'
info_df = DFBuilder()
for model_name in model_names:
    model_name_d = strings.get_dict_from_string(model_name)
    method = model_name_d['method']
    load_roodir = f'../save/{model_name}/survey=alerceZTFv7.1~bands=gr~mode=onlySNe~method={method}'
    print(load_roodir)
    files, files_ids, kfs = ftfiles.gather_files_by_kfold(load_roodir, kf, set_name,
        fext='d',
        imbalanced_kf_mode='oversampling', # error oversampling
        random_state=RANDOM_STATE,
        )
    
    print(f'{files_ids}({len(files_ids)}#)')
    if len(files)==0:
        continue

    for metric_name in metric_names:
        print([f()['thdays_class_metrics_df'][f'b-{curve_metric_name}'].values for f in files])
        assert 0
        xe_metric = XError([f()['thdays_class_metrics_df'].loc[f()['thdays_class_metrics_df']['_thday']==thday][f'b-{metric_name}'].item() for f in files])
        print(metric_name, xe_metric)
        #xe_dict[metric_name] = xe_metric

# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
from fuzzytools.files import load_pickle, save_pickle
from fuzzytools.datascience.xerror import XError
from fuzzytools.dataframes import DFBuilder
from fuzzytools.latex.latex_tables import LatexTable
from fuzzytools.files import save_pickle

METRICS_D = {
    f'aucroc':{'k':1, 'mn':'AUCROC'},
    f'precision':{'k':1, 'mn':'Precision'},
    f'recall':{'k':1, 'mn':'Recall'},
    f'f1score':{'k':1, 'mn':'$F_1$score'},
    f'aucpr':{'k':1, 'mn':'AUCPR'},
    f'gmean':{'k':1, 'mn':'Gmean'},
    f'accuracy':{'k':1, 'mn':'Accuracy'},
    }

metric_names = [
    'precision',
    'recall',
    'f1score',
    'aucroc',
    'aucpr',
    ]
info_df = DFBuilder()
train_configs = ['r', 's', 'r+s']
for train_config in train_configs:
    #aux_r = []
    for method in methods:
    #d = {}
    #for metric in metric_names:
    #mn = METRICS_D[metric]['mn']
    load_roodir = f'../save/performance/exp=rf_eval~train_config={train_config}/survey=alerceZTFv7.1~bands=gr~mode=onlySNe~method={method}'
    print(load_roodir)
    try:
        files, files_ids, kfs = ftfiles.gather_files_by_kfold(load_roodir, kf, set_name,
            fext='d',
            imbalanced_kf_mode='oversampling', # error oversampling
            random_state=RANDOM_STATE,
            )
    except:
        continue

    print(f'{files_ids}({len(files_ids)}#)')
    if len(files)==0:
        continue
    #xe_dict = {}
    for metric_name in metric_names:
        xe_metric = XError([f()['thdays_class_metrics_df'].loc[f()['thdays_class_metrics_df']['_thday']==thday][f'b-{metric_name}'].item() for f in files])
        print(metric_name, xe_metric)
        #xe_dict[metric_name] = xe_metric

    #brecall_xe = xe_dict['b-recall']
    #bf1score_xe = xe_dict['b-f1score']

    #features = files[0]()['features']
    #metric_xe = XError([f()['metrics_dict'][metric]*dmetrics[metric]['k'] for f in files])
    #d[mn] = metric_xe
    #print(len(metric_xe))

    #if not train_config=='r': # mean across methods in real case
    #    info_df.append(f'synthetic-method={method} [{train_config}]', d)
    #else:
    #    aux_r.append(d)

#if train_config=='r': # mean across methods in real case
 #   for r in aux_r:
  #      print(r)
   # new_d = {k:sum([r[k] for r in aux_r]) for k in d.keys()}
    #info_df.append(f'synthetic-method=no-method [{train_config}]', new_d)
    
display(info_df())

ttest_metric = 'b-AUCROC'
info_df['synthetic-method=spm-mcmc-estw [r+s]'][ttest_metric].gt_ttest(info_df['synthetic-method=no-method [r]'][ttest_metric], verbose=1)


latex_kwargs = {
    'label':'tab:',
    'bold_axis':'columns',
}
latex_table = LatexTable(info_df(), **latex_kwargs)
print(latex_table)
